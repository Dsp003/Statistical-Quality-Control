# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def comb(x,y):
    u = p = 1
    k, t = min(x-y, y), max(x-y, y)
    while(x > t):
        u *= x
        p *= k
        x -= 1
        k -= 1
    return u / p

# %%
pop = np.random.randint(100, size=(10000))
ls = list()
for i in range(1000):
    ls.append(pop[np.random.choice(10000, size=(100), replace=False)].mean())
plt.figure()
plt.hist(ls, bins=100)
plt.title('Histogram representing the spread of sample means')
plt.ylabel('frequecy')
plt.xlabel('mean of samples')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'mean of samples')

# %%
out = pd.DataFrame({'Generated Data': [np.mean(pop), np.var(pop)],
                    'Random Samples of size 100': [np.mean(ls), np.var(ls)],
                    'Predicted by Central Limit Theorem': [np.mean(pop), (np.var(pop)) / 100]
                   }, index=['mean', 'variance'])
out
# Out:
#           Generated Data  Random Samples of size 100  \
# mean           49.689400                   49.772930
# variance      834.513728                    8.774416
#
#           Predicted by Central Limit Theorem
# mean                               49.689400
# variance                            8.345137

# %%
plt.figure()
pd.Series(ls).plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:ylabel='Density'>
